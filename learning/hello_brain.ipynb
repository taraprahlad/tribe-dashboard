# %%
# !pip install nilearn
from nilearn import datasets, plotting

stat_img = datasets.load_sample_motor_activation_image()

plotting.plot_stat_map(stat_img, title="My first brain render")

view = plotting.view_img(stat_img, title="Interactive brain")
view
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:820: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;title&gt;Nilearn - Interactive brain&lt;/title&gt;
#         &lt;link rel=&quot;icon&quot;
#               type=&quot;image/x-icon&quot;
#               href=&quot;https://raw.githubusercontent.com/nilearn/nilearn/main/doc/logos/favicon.ico&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot;
#               content=&quot;width = device-width, initial-scale = 1&quot;
#               charset=&quot;UTF-8&quot; /&gt;
#
#
#     &lt;/head&gt;
#     &lt;body&gt;
#         &lt;main&gt;
#
#
#
# &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
# ...
